# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('AP data - merged.csv' , delimiter=',')
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6492\2333620618.py:1: DtypeWarning: Columns (0,1,2,3,4,5,6,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('AP data - merged.csv' , delimiter=',')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1288555 entries, 0 to 1288554
# Data columns (total 10 columns):
#  #   Column                                     Non-Null Count    Dtype
# ---  ------                                     --------------    -----
#  0   Date                                       293475 non-null   object
#  1   Time                                       293474 non-null   object
#  2   Station Name                               293474 non-null   object
#  3   Ozone                                      293474 non-null   object
#  4   Nitric oxide                               293474 non-null   object
#  5   Nitrogen dioxide                           293474 non-null   object
#  6   Nitrogen oxides as nitrogen dioxide        293474 non-null   object
#  7   Sulphur dioxide                            1288551 non-null  object
#  8   Carbon monoxide                            1288551 non-null  object
# ...

# %%
df.head(5)
# Out:
#          Date      Time    Station Name    Ozone Nitric oxide  \
# 0  01/01/2004  01:00:00  Bristol Centre  No data      No data
# 1  01/01/2004  02:00:00  Bristol Centre       66      No data
# 2  01/01/2004  03:00:00  Bristol Centre       66            0
# 3  01/01/2004  04:00:00  Bristol Centre       58            1
# 4  01/01/2004  05:00:00  Bristol Centre       58            1
#
#   Nitrogen dioxide Nitrogen oxides as nitrogen dioxide Sulphur dioxide  \
# 0          No data                             No data         No data
# 1          No data                             No data               0
# 2               13                                  13               0
# 3               11                                  13               0
# 4               13                                  15               0
#
#   Carbon monoxide PM10 particulate matter (Hourly measured)
# 0         No data                                         4
# ...

# %%
df_clean = df.replace('No data', np.NaN)
df_clean = df.sort_values(by=['Date', 'Time', 'Station Name'])
df_clean = df.reset_index(drop=True)

# %%
df_clean.head(10)
# Out:
#          Date      Time    Station Name    Ozone Nitric oxide  \
# 0  01/01/2004  01:00:00  Bristol Centre  No data      No data
# 1  01/01/2004  02:00:00  Bristol Centre       66      No data
# 2  01/01/2004  03:00:00  Bristol Centre       66            0
# 3  01/01/2004  04:00:00  Bristol Centre       58            1
# 4  01/01/2004  05:00:00  Bristol Centre       58            1
# 5  01/01/2004  06:00:00  Bristol Centre       56            0
# 6  01/01/2004  07:00:00  Bristol Centre       56            0
# 7  01/01/2004  08:00:00  Bristol Centre       50            0
# 8  01/01/2004  09:00:00  Bristol Centre       54            0
# 9  01/01/2004  10:00:00  Bristol Centre       58            3
#
#   Nitrogen dioxide Nitrogen oxides as nitrogen dioxide Sulphur dioxide  \
# 0          No data                             No data         No data
# 1          No data                             No data               0
# ...

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1288555 entries, 0 to 1288554
# Data columns (total 10 columns):
#  #   Column                                     Non-Null Count    Dtype
# ---  ------                                     --------------    -----
#  0   Date                                       293475 non-null   object
#  1   Time                                       293474 non-null   object
#  2   Station Name                               293474 non-null   object
#  3   Ozone                                      293474 non-null   object
#  4   Nitric oxide                               293474 non-null   object
#  5   Nitrogen dioxide                           293474 non-null   object
#  6   Nitrogen oxides as nitrogen dioxide        293474 non-null   object
#  7   Sulphur dioxide                            1288551 non-null  object
#  8   Carbon monoxide                            1288551 non-null  object
# ...

# %%
df_clean = df_clean.dropna(subset=['Date'])
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 293475 entries, 0 to 1288554
# Data columns (total 10 columns):
#  #   Column                                     Non-Null Count   Dtype
# ---  ------                                     --------------   -----
#  0   Date                                       293475 non-null  object
#  1   Time                                       293474 non-null  object
#  2   Station Name                               293474 non-null  object
#  3   Ozone                                      293474 non-null  object
#  4   Nitric oxide                               293474 non-null  object
#  5   Nitrogen dioxide                           293474 non-null  object
#  6   Nitrogen oxides as nitrogen dioxide        293474 non-null  object
#  7   Sulphur dioxide                            293474 non-null  object
#  8   Carbon monoxide                            293474 non-null  object
#  9   PM10 particulate matter (Hourly measured)  293474 non-null  object
# ...

# %%
df_clean[(df_clean['Date'].notnull()) & (df_clean['Station Name'].isnull())]
# Out:
#       Date Time Station Name Ozone Nitric oxide Nitrogen dioxide  \
# 14979  End  NaN          NaN   NaN          NaN              NaN
#
#       Nitrogen oxides as nitrogen dioxide Sulphur dioxide Carbon monoxide  \
# 14979                                 NaN             NaN             NaN
#
#       PM10 particulate matter (Hourly measured)
# 14979                                       NaN

# %%
df_clean['Date2'] = pd.to_datetime(df_clean['Date'], format='%m/%d/%Y', errors='coerce')
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 293475 entries, 0 to 1288554
# Data columns (total 11 columns):
#  #   Column                                     Non-Null Count   Dtype
# ---  ------                                     --------------   -----
#  0   Date                                       293475 non-null  object
#  1   Time                                       293474 non-null  object
#  2   Station Name                               293474 non-null  object
#  3   Ozone                                      293474 non-null  object
#  4   Nitric oxide                               293474 non-null  object
#  5   Nitrogen dioxide                           293474 non-null  object
#  6   Nitrogen oxides as nitrogen dioxide        293474 non-null  object
#  7   Sulphur dioxide                            293474 non-null  object
#  8   Carbon monoxide                            293474 non-null  object
#  9   PM10 particulate matter (Hourly measured)  293474 non-null  object
# ...

# %%
df_clean[(df_clean['Date'].notnull()) & (df_clean['Date2'].isnull())]
# Out:
#                Date      Time       Station Name     Ozone Nitric oxide  \
# 288      13/01/2004  01:00:00     Bristol Centre        74            0
# 289      13/01/2004  02:00:00     Bristol Centre        76      No data
# 290      13/01/2004  03:00:00     Bristol Centre        76            0
# 291      13/01/2004  04:00:00     Bristol Centre        88            0
# 292      13/01/2004  05:00:00     Bristol Centre        84            0
# ...             ...       ...                ...       ...          ...
# 1200902  31/12/2013  20:00:00  Bristol St Paul's  42.10927       3.4438
# 1200903  31/12/2013  21:00:00  Bristol St Paul's  51.68863       2.6608
# 1200904  31/12/2013  22:00:00  Bristol St Paul's  54.28304      1.80017
# 1200905  31/12/2013  23:00:00  Bristol St Paul's  53.03573      1.83977
# 1200906  31/12/2013  24:00:00  Bristol St Paul's  63.66283      1.40883
#
#         Nitrogen dioxide Nitrogen oxides as nitrogen dioxide Sulphur dioxide  \
# ...
